# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15873, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 15873 (delta 12), reused 7 (delta 7), pack-reused 15850 (from 3)
# Receiving objects: 100% (15873/15873), 14.50 MiB | 13.13 MiB/s, done.
# Resolving deltas: 100% (10679/10679), done.

# %%
# change makefile to have GPU and OPENCV and CUDA enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
# ...

# %%
# !cp /content/drive/MyDrive/obj.zip ../
# to copy contents to outter of current dir

# %%
# !unzip ../obj.zip -d data/
# unzip data to darknet==>data==>obj
# Out:
# Archive:  ../obj.zip
#    creating: data/obj/
#   inflating: data/obj/1.jpeg
#   inflating: data/obj/2.jpeg
#   inflating: data/obj/3.jpeg
#   inflating: data/obj/4.jpeg
#   inflating: data/obj/5.jpeg
#   inflating: data/obj/6.jpeg
#   inflating: data/obj/7.jpeg
#   inflating: data/obj/8.jpeg
#   inflating: data/obj/9.jpeg
#   inflating: data/obj/10.jpeg
#   inflating: data/obj/1.txt
#   inflating: data/obj/classes.txt
#   inflating: data/obj/2.txt
#   inflating: data/obj/3.txt
#   inflating: data/obj/4.txt
#   inflating: data/obj/5.txt
#   inflating: data/obj/6.txt
#   inflating: data/obj/7.txt
#   inflating: data/obj/8.txt
#   inflating: data/obj/11.jpeg
#   inflating: data/obj/9.txt
#   inflating: data/obj/10.txt
#   inflating: data/obj/11.txt
#   inflating: data/obj/12.txt
#   inflating: data/obj/13.txt
#   inflating: data/obj/14.txt
#   inflating: data/obj/15.txt
#   inflating: data/obj/16.txt
#   inflating: data/obj/17.txt
#   inflating: data/obj/18.txt
# ...

# %%
# !cp /content/drive/MyDrive/obj.data ./data

# %%
# !cp /content/drive/MyDrive/obj.names ./data

# %%
# !cp /content/drive/MyDrive/yolov3_custom.cfg ./data

# %%
# !cp /content/drive/MyDrive/generate_train.py ./

# %%
# !python generate_train.py

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2025-01-21 03:12:54--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  38.5MB/s    in 4.3s
#
# 2025-01-21 03:12:58 (36.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !/content/darknet/darknet detector train /content/darknet/data/obj.data /content/darknet/data/yolov3_custom.cfg /content/darknet/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.156298), count: 2, class_loss = 0.843058, iou_loss = 3.041126, total_loss = 3.884184
#  total_bbox = 13703, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.482136), count: 1, class_loss = 0.585682, iou_loss = 0.358836, total_loss = 0.944518
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.390516), count: 3, class_loss = 1.122732, iou_loss = 1.707421, total_loss = 2.830153
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.271331, iou_loss = 0.000000, total_loss = 0.271331
#  total_bbox = 13707, rewritten_bbox = 0.000000 %
# ...
